# %%
import joblib
import pandas as pd

# %%
from google.colab import files
files.download("best_model.pkl")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from google.colab import files
#       2 files.download("best_model.pkl")
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
best_model = joblib.load(r"C:\Users\Lenovo\Downloads\GitHub projects\Disease Prediction from Medical Data\Heart-Disease-Prediction\models\heart_disease_random_forest.pkl)
print("Model loaded successfully!")
# Out:
#   Cell In[5], line 1
#     best_model = joblib.load(r"C:\Users\Lenovo\Downloads\GitHub projects\Disease Prediction from Medical Data\Heart-Disease-Prediction\models\heart_disease_random_forest.pkl)
#                              ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
new_patient = pd.DataFrame({
    'age': [63],
    'sex': [1],
    'cp': [3],
    'trestbps': [145],
    'chol': [233],
    'fbs': [1],
    'restecg': [0],
    'thalach': [150],
    'exang': [0],
    'oldpeak': [2.3],
    'slope': [0],
    'ca': [0],
    'thal': [1]
})

prediction = best_model.predict(new_patient)

if prediction[0] == 1:
    print("Heart Disease Detected")
else:
    print("No Heart Disease")
